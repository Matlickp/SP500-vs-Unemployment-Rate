# %%
# Import dependencies
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import datetime as dt
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import style
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates
import pymongo
style.use('ggplot')

# %%
# Set start and end data for query
start = dt.datetime(2000,1,1)
end = dt.datetime(2018,12,31)

# Pull data from Yahoo and create df for SPY
df = web.DataReader('SPY', 'yahoo', start, end)
df.head()
# Out:
#                   High         Low        Open     Close      Volume  \
# Date
# 2000-01-03  148.250000  143.875000  148.250000  145.4375   8164300.0
# 2000-01-04  144.062500  139.640594  143.531204  139.7500   8089800.0
# 2000-01-05  141.531204  137.250000  139.937500  140.0000  12177900.0
# 2000-01-06  141.500000  137.750000  139.625000  137.7500   6227200.0
# 2000-01-07  145.750000  140.062500  140.312500  145.7500   8066500.0
#
#              Adj Close
# Date
# 2000-01-03  101.872139
# 2000-01-04   97.888344
# 2000-01-05   98.063423
# 2000-01-06   96.487427
# 2000-01-07  102.091049

# %%
# Save df to csv
df.to_csv('Data/spy.csv')

# %%
# Read data from csv
spy_df = pd.read_csv('Data/spy.csv', parse_dates=True, index_col=0)
spy_df.head()
# Out:
#                   High         Low        Open     Close      Volume  \
# Date
# 2000-01-03  148.250000  143.875000  148.250000  145.4375   8164300.0
# 2000-01-04  144.062500  139.640594  143.531204  139.7500   8089800.0
# 2000-01-05  141.531204  137.250000  139.937500  140.0000  12177900.0
# 2000-01-06  141.500000  137.750000  139.625000  137.7500   6227200.0
# 2000-01-07  145.750000  140.062500  140.312500  145.7500   8066500.0
#
#              Adj Close
# Date
# 2000-01-03  101.872139
# 2000-01-04   97.888344
# 2000-01-05   98.063423
# 2000-01-06   96.487427
# 2000-01-07  102.091049

# %%
# Create a column that shows the 100 Day Moving Average
spy_df['100MA'] = spy_df['Adj Close'].rolling(window=100, min_periods=0).mean()

# Drop unneccessary columns
spy_df2 = spy_df.drop(["High","Low","Open","Close"], axis=1)

# %%
# Rename columns to prep for merge
spy_df2.rename(columns={"Volume":"SPY Volume", "Adj Close":"SPY AdjClose", "100MA":"SPY 100MA"}, inplace=True)
spy_df2.head()
# Out:
#             SPY Volume  SPY AdjClose   SPY 100MA
# Date
# 2000-01-03   8164300.0    101.872139  101.872139
# 2000-01-04   8089800.0     97.888344   99.880241
# 2000-01-05  12177900.0     98.063423   99.274635
# 2000-01-06   6227200.0     96.487427   98.577833
# 2000-01-07   8066500.0    102.091049   99.280476

# %%
# Pull data from Yahoo and create df for VIX 
df = web.DataReader('^VIX', 'yahoo', start, end)
df.head()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2000-01-03  26.150000  23.980000  24.360001  24.209999       0  24.209999
# 2000-01-04  27.180000  24.799999  24.940001  27.010000       0  27.010000
# 2000-01-05  29.000000  25.850000  27.980000  26.410000       0  26.410000
# 2000-01-06  26.709999  24.700001  26.680000  25.730000       0  25.730000
# 2000-01-07  25.170000  21.719999  25.139999  21.719999       0  21.719999

# %%
# Save df to csv
df.to_csv('Data/vix.csv')

# %%
# Read data from csv
vix_df = pd.read_csv('Data/vix.csv', parse_dates=True, index_col=0)
vix_df.head()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2000-01-03  26.150000  23.980000  24.360001  24.209999       0  24.209999
# 2000-01-04  27.180000  24.799999  24.940001  27.010000       0  27.010000
# 2000-01-05  29.000000  25.850000  27.980000  26.410000       0  26.410000
# 2000-01-06  26.709999  24.700001  26.680000  25.730000       0  25.730000
# 2000-01-07  25.170000  21.719999  25.139999  21.719999       0  21.719999

# %%
# Create a column that shows the 100 Day Moving Average
vix_df['100MA'] = vix_df['Adj Close'].rolling(window=100, min_periods=0).mean()

# Drop unneccessary columns
vix_df2 = vix_df.drop(["High","Low","Open","Close"], axis=1)

# %%
# Rename columns to prep for merge
vix_df2.rename(columns={"Volume":"VIX Volume", "Adj Close":"VIX AdjClose", "100MA":"VIX 100MA"}, inplace=True)
vix_df2.head()
# Out:
#             VIX Volume  VIX AdjClose  VIX 100MA
# Date
# 2000-01-03           0     24.209999  24.209999
# 2000-01-04           0     27.010000  25.610000
# 2000-01-05           0     26.410000  25.876666
# 2000-01-06           0     25.730000  25.840000
# 2000-01-07           0     21.719999  25.016000

# %%
# Join SPY data and VIX data on date
market_df= spy_df2.join(vix_df2, how="outer", on="Date")
market_df = market_df.reset_index()
market_df.head()
# Out:
#         Date  SPY Volume  SPY AdjClose   SPY 100MA  VIX Volume  VIX AdjClose  \
# 0 2000-01-03   8164300.0    101.872139  101.872139           0     24.209999
# 1 2000-01-04   8089800.0     97.888344   99.880241           0     27.010000
# 2 2000-01-05  12177900.0     98.063423   99.274635           0     26.410000
# 3 2000-01-06   6227200.0     96.487427   98.577833           0     25.730000
# 4 2000-01-07   8066500.0    102.091049   99.280476           0     21.719999
#
#    VIX 100MA
# 0  24.209999
# 1  25.610000
# 2  25.876666
# 3  25.840000
# 4  25.016000

# %%
# Read Unemployment data from csv
unemployment_df = pd.read_csv('Data/Unemployment rate.csv', parse_dates=True, index_col=0)
unemployment_df = unemployment_df.reset_index()
# Multiply by 10 to make line comparable on chart
unemployment_df.Rate *=10
unemployment_df.head()
# Out:
#         Date  Rate
# 0 2000-01-01  40.0
# 1 2000-02-01  41.0
# 2 2000-03-01  40.0
# 3 2000-04-01  38.0
# 4 2000-05-01  40.0

# %%
# Create connection to MongoDB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
market_db = client.marketData_db

# Declare the collection
collection = market_db.market_df

# Convert market_df to dictionary
market_data = market_df.to_dict(orient='records')

# Insert market dictionary into Mongo
collection.insert_many(market_data)

# %%
# Declare the database
unemployment_db = client.marketData_db

# Declare the collection
collection = unemployment_db.unemployment_df

# Convert unemployment_df to dictionary
unemployment_data = unemployment_df.to_dict(orient='records')

# Insert unemployment dictionary into Mongo
collection.insert_many(unemployment_data)

# %%
# Query MongoDB for market data
results = market_db.market_df.find()

# Create list to hold data
market_df = []

# Loop through mongoDB and add info to list
for result in results:
    market_df.append(result)
print(market_df)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Create dataframe from market data list
market_df = pd.DataFrame(market_df)

# Drop id column
market_df.drop(['_id'], axis=1, inplace=True)

# %%
# Format date
market_df.Date = pd.to_datetime(market_df.Date)

# Set date as index
market_df.set_index("Date", inplace=True)
market_df.head()
# Out:
#              SPY 100MA  SPY AdjClose  SPY Volume  VIX 100MA  VIX AdjClose  \
# Date
# 2000-01-03  101.872139    101.872139   8164300.0  24.209999     24.209999
# 2000-01-04   99.880241     97.888344   8089800.0  25.610000     27.010000
# 2000-01-05   99.274635     98.063423  12177900.0  25.876666     26.410000
# 2000-01-06   98.577833     96.487427   6227200.0  25.840000     25.730000
# 2000-01-07   99.280476    102.091049   8066500.0  25.016000     21.719999
#
#             VIX Volume
# Date
# 2000-01-03         0.0
# 2000-01-04         0.0
# 2000-01-05         0.0
# 2000-01-06         0.0
# 2000-01-07         0.0

# %%
# Query MongoDB for unemployment data
results = market_db.unemployment_df.find()

# create empty list to store data
unemployment_df = []

# Loop through results and append list
for result in results:
    unemployment_df.append(result)
print(unemployment_df)
# Out:
# [{'_id': ObjectId('5c3a445d8646f83a4c7ba962'), 'Date': datetime.datetime(2000, 1, 1, 0, 0), 'Rate': 40.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba963'), 'Date': datetime.datetime(2000, 2, 1, 0, 0), 'Rate': 41.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba964'), 'Date': datetime.datetime(2000, 3, 1, 0, 0), 'Rate': 40.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba965'), 'Date': datetime.datetime(2000, 4, 1, 0, 0), 'Rate': 38.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba966'), 'Date': datetime.datetime(2000, 5, 1, 0, 0), 'Rate': 40.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba967'), 'Date': datetime.datetime(2000, 6, 1, 0, 0), 'Rate': 40.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba968'), 'Date': datetime.datetime(2000, 7, 1, 0, 0), 'Rate': 40.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba969'), 'Date': datetime.datetime(2000, 8, 1, 0, 0), 'Rate': 41.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96a'), 'Date': datetime.datetime(2000, 9, 1, 0, 0), 'Rate': 39.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96b'), 'Date': datetime.datetime(2000, 10, 1, 0, 0), 'Rate': 39.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96c'), 'Date': datetime.datetime(2000, 11, 1, 0, 0), 'Rate': 39.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96d'), 'Date': datetime.datetime(2000, 12, 1, 0, 0), 'Rate': 39.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96e'), 'Date': datetime.datetime(2001, 1, 1, 0, 0), 'Rate': 42.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba96f'), 'Date': datetime.datetime(2001, 2, 1, 0, 0), 'Rate': 42.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba970'), 'Date': datetime.datetime(2001, 3, 1, 0, 0), 'Rate': 43.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba971'), 'Date': datetime.datetime(2001, 4, 1, 0, 0), 'Rate': 44.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba972'), 'Date': datetime.datetime(2001, 5, 1, 0, 0), 'Rate': 43.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba973'), 'Date': datetime.datetime(2001, 6, 1, 0, 0), 'Rate': 45.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba974'), 'Date': datetime.datetime(2001, 7, 1, 0, 0), 'Rate': 46.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba975'), 'Date': datetime.datetime(2001, 8, 1, 0, 0), 'Rate': 49.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba976'), 'Date': datetime.datetime(2001, 9, 1, 0, 0), 'Rate': 50.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba977'), 'Date': datetime.datetime(2001, 10, 1, 0, 0), 'Rate': 53.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba978'), 'Date': datetime.datetime(2001, 11, 1, 0, 0), 'Rate': 55.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba979'), 'Date': datetime.datetime(2001, 12, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97a'), 'Date': datetime.datetime(2002, 1, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97b'), 'Date': datetime.datetime(2002, 2, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97c'), 'Date': datetime.datetime(2002, 3, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97d'), 'Date': datetime.datetime(2002, 4, 1, 0, 0), 'Rate': 59.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97e'), 'Date': datetime.datetime(2002, 5, 1, 0, 0), 'Rate': 58.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba97f'), 'Date': datetime.datetime(2002, 6, 1, 0, 0), 'Rate': 58.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba980'), 'Date': datetime.datetime(2002, 7, 1, 0, 0), 'Rate': 58.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba981'), 'Date': datetime.datetime(2002, 8, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba982'), 'Date': datetime.datetime(2002, 9, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba983'), 'Date': datetime.datetime(2002, 10, 1, 0, 0), 'Rate': 57.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba984'), 'Date': datetime.datetime(2002, 11, 1, 0, 0), 'Rate': 59.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba985'), 'Date': datetime.datetime(2002, 12, 1, 0, 0), 'Rate': 60.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba986'), 'Date': datetime.datetime(2003, 1, 1, 0, 0), 'Rate': 58.0}, {'_id': ObjectId('5c3a445d8646f83a4c7ba987'), 'Date': datetime.datet ...

# %%
# Create dataframe from list
unemployment_df = pd.DataFrame(unemployment_df)

# Drop id column
unemployment_df.drop(['_id'], axis=1, inplace=True)

# %%
# Format Date
unemployment_df.Date = pd.to_datetime(unemployment_df.Date)

# Set date to index
unemployment_df.set_index("Date", inplace=True)

#Change Rate to Unemployment Rate
unemployment_df.head()
# Out:
#             Rate
# Date
# 2000-01-01  40.0
# 2000-02-01  41.0
# 2000-03-01  40.0
# 2000-04-01  38.0
# 2000-05-01  40.0

# %%
# Set up graph area
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

# Plot Adj Close and 100 Average lines on first plot area 
vix_close = ax1.plot(market_df.index, market_df['VIX AdjClose'])
vix_average = ax1.plot(market_df.index,market_df['VIX 100MA'])
spy_close = ax1.plot(market_df.index, market_df['SPY AdjClose'])
spy_average = ax1.plot(market_df.index,market_df['SPY 100MA'])

# Plot the SPY volume bars in second plot area
spy_volume = ax2.bar(market_df.index, market_df['SPY Volume'])

# Add Title and Labels
ax1.set_title("SP500 vs Volatility Index")
ax1.set_xlabel("Years")
ax1.set_ylabel("Price")
ax2.set_ylabel("Units")
# Add legend
ax1.legend()
ax2.legend("Vol", loc="best", fontsize="x-small")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Save figure
plt.savefig('SPYvsVIX.png')

# %%
# Set up plot areas
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

# Plot Adj Close and 100 Day Moving Average on top plot area
ax1.plot(market_df.index, market_df['VIX AdjClose'])
ax1.plot(market_df.index,market_df['VIX 100MA'])
ax1.plot(market_df.index, market_df['SPY AdjClose'])
ax1.plot(market_df.index,market_df['SPY 100MA'])

# Plot SPy Volume bars in second plot area
ax2.bar(market_df.index, market_df['SPY Volume'])

# Plot the Unemployment Rate line in top plot area
ax1.plot(unemployment_df.index, unemployment_df['Rate'])

# Add Title and Labels
ax1.set_title("Unemployment Rate vs Market Action")
ax1.set_xlabel("Years")
ax1.set_ylabel("Price")
ax2.set_ylabel("Units")
# Add legend
ax1.legend()
ax2.legend("Vol", loc="best", fontsize="x-small")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Save image
plt.savefig("Unemployment vs Market")
